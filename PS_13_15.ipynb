# %% [markdown]
# ![Screenshot_4.png](data:image/png;base64,...)

# %%
def S_T_I(text):
    return int(text)

# %%
print(S_T_I("1234"))
# Out:
# 1234

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)

# %%
def remove(text):
  after_remove= text[1:len(text)-1]
  return after_remove

# %%
print(remove("aabcdd"))
# Out:
# abcd

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %%
def repeate(repeate_time,text):
  after_repeate=""
  for i in range(repeate_time):
    after_repeate+=text
  return after_repeate

# %%
print(repeate(6,"I"))
print(repeate(5,"Hello"))
# Out:
# IIIIII
# HelloHelloHelloHelloHello
