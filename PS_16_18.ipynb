# %% [markdown]
# ![Screenshot_3.png](data:image/png;base64,...)

# %%
def remove_space(text):
  after_remove= text.replace(" ","")
  return after_remove

# %%
print(remove_space("8 j 8 mbbkjdf kjkpl   ll l;l "))
# Out:
# 8j8mbbkjdfkjkpllll;l

# %% [markdown]
# ![Screenshot_4.png](data:image/png;base64,...)

# %%
def str_count(text,character):
  count=0
  for i in (text):
    if i == character:
      count+=1
  return count

# %%
print(str_count("Hello",'o'))
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def millisecond_count(h,m,s):
    result=s*1000 + m*60000 + h*3600000
    return result

# %%
print("result = ", millisecond_count(0,1,1))
# Out:
# result =  61000
